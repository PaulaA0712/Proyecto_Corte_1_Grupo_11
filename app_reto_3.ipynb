# %% [markdown]
# # Reto 3: ECONONOMÍA - Dolar Track

# %%
"""
DOLAR-TRACK
Este programa solicita al usuario que ingrese el valor de la TRM (Tasa Representativa del Mercado) para cada uno de los 7 días de la semana.
Luego, calcula el promedio de la TRM, cuenta cuántos días tienen una TRM mayor o menor que el promedio, y determina el valor máximo, mínimo y la volatilidad (diferencia entre el valor máximo y mínimo) de la TRM durante esos días.
Autor: Valeria Morales Giraldo
"""
# Lista para almacenar los valores de la TRM de cada dia
trm = [0,0,0,0,0,0,0] 
#Se inicializan las variables para el promedio, el conteo de dias mayores y menores al promedio, el valor maximo, el valor minimo y la volatilidad.
promedio = 0
dias_mayores = 0
dias_menores = 0    
 
# Se solicita al usuario que ingrese el valor de la TRM para cada uno de los 7 días, y se valida que el valor ingresado no sea negativo. Luego, se suma cada valor de la TRM al promedio para calcular el promedio total al final del ciclo.
for i in range(7):
    trm_dia = float(input("Digite el TRM del dia " + str(i+1) + ": "))
    if trm_dia < 0:
        print("El TRM no puede ser negativo. Por favor, ingrese un valor válido.")
        while trm_dia < 0:
            trm_dia = float(input("Digite el TRM del dia " + str(i+1) + ": "))
    trm[i] = trm_dia
    promedio = trm_dia + promedio
promedio = promedio / 7
 
# Se recorre la lista de TRM para contar cuántos días tienen una TRM mayor o menor que el promedio.
for i in trm:
    if i > promedio:
        dias_mayores = dias_mayores + 1
    elif i < promedio:
        dias_menores = dias_menores + 1
 
# Se inicializan las variables para el valor máximo, mínimo y la volatilidad, y se recorren los valores de la TRM para encontrar el valor máximo y mínimo.
valor_maximo = float 
valor_maximo = trm[0]
valor_minimo = float
valor_minimo = trm[0]
votalidad = float
votalidad = 0
 
# Se recorre la lista de TRM para encontrar el valor máximo y mínimo, y luego se calcula la volatilidad como la diferencia entre el valor máximo y mínimo.
for i in trm:
    if valor_maximo < i:
        valor_maximo = i
 
for i in trm:
    if valor_minimo > i:
        valor_minimo = i
 
votalidad = valor_maximo - valor_minimo
 
# Finalmente, se imprimen los resultados: el promedio de la TRM, el número de días con TRM mayor y menor al promedio, y el valor de la volatilidad.
print("El promedio de la TRM es: " + str(promedio))
print("El numero de dias con TRM mayor al promedio es: " + str(dias_mayores))
print("El numero de dias con TRM menor al promedio es: " + str(dias_menores))
print("El valor de la votalidad es: " + str(votalidad))
# Out:
# El promedio de la TRM es: 3678.5714285714284
# El numero de dias con TRM mayor al promedio es: 3
# El numero de dias con TRM menor al promedio es: 4
# El valor de la votalidad es: 390.0
